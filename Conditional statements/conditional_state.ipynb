# %% [markdown]
# Commditional statement

# %% [markdown]
# ### conditional statements

# %% [markdown]
# ### are real work senerios where if a certain statement of code or block gets executed

# %%
### eligibility for driving on meeting a certain condition
### if a condition is meeting a block code will be executed 

age=int(input("ask age:"))

if age>=18:
    print("your are eligiable for driving")
else:
    print("your are not eligiable")
# Out:
# your are not eligiable

# %%
### if is a most imp condition 
### else is a second condition if IF fails 
### else if is a third condition if else fails

### eg: who is the tallest
Amit=int(input("enter your age"))
mujib=int(input("enter your age"))
saba=int(input("enter your age"))

if Amit>mujib>saba:
    print("amit aged")
elif saba>mujib:
    print("saba is aged")
else:
    print(" mujib is aged")
# Out:
# saba is aged

# %% [markdown]
# Nested Conditionaly statemennt

# %% [markdown]
# if condition had insise an if condition

# %% [markdown]
# mutiple if statement insaide a if sattement

# %%
### eg: who is the aged
Amit=int(input("enter Amit age"))
mujib=int(input("enter mujib age"))
saba=int(input("enter saba age"))

if Amit>mujib:
    if mujib>saba or Amit>saba:
        print("nested worked")
elif mujib>Amit:
    if mujib>saba or Amit>saba:
        print("second")
else:
    print("mome")
# Out:
# nested worked

# %%
# wheater crrent year is leap year 
year=int(input("enter the year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print("current year is leap year")
        else:
            print("noo leap year")
    else:
        print("year is leap year")
else:
    print("its not a leap year")
# Out:
# year is leap year
