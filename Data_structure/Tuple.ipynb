# %% [markdown]
# ### tuple

# %% [markdown]
# ### it is second type of data structure

# %% [markdown]
# ### in an ordered way

# %% [markdown]
# #### just like list but tuples are not mutable

# %% [markdown]
# ### list is mutable because we can replace the value in list but in tuple we cannot replace the value

# %% [markdown]
# ### list syntex is []
# ### tuple syntix is ()

# %%
a=tuple()

# %%
type(a)
# Out:
# tuple

# %%
tuple_value= (1,2,3,4,5)

# %%
tuple_value
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# # ####tuples are stored in an ordered way and in a index manner

# %% [markdown]
# ### it is immutable

# %% [markdown]
# ### tuple can store any data like bool syring int etc

# %% [markdown]
# ### tuples are ordered and indexed

# %% [markdown]
# ### method in tuples

# %% [markdown]
# ### 1 count and indexed

# %%
tuple_method = (1,2,3,4,5,6,7,8,9)

# %%
tuple_method.index(7)
# Out:
# 6

# %%
tuple_method.count(9)
# Out:
# 1

# %% [markdown]
# ### pacing and unpacking of tyuples

# %%
### packing

# %%
a = 1,2,3,4,5

# %%
type(a)
# Out:
# tuple

# %%
### unpacking with *

# %%
a,b,c,v = (1,2,3,45)

# %%
a
# Out:
# 1

# %%
v
# Out:
# 45

# %%
a,*b,c=(1,2,3,4,5,6,7,8,9)

# %%
a
# Out:
# 1

# %%
c
# Out:
# 9

# %%
b
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ### Nested List

# %%
nested_list =[[1,2,3,],[4,5,6],[7,8,9]]

# %%
nested_list[0][:]
# Out:
# [1, 2, 3]

# %%
nested_list[0][2]
# Out:
# 3

# %%
tuple_list = [(1,2,3),(4,5,6),(7,8,9)]

# %%
tuple_list[0][:]
# Out:
# (1, 2, 3)

# %%
tuple_list[0][2]
# Out:
# 3

# %%
### irreting tupele inside a tuple

# %%
for i in tuple_list:
    for j in i:
        print(j,sep=" ")
    print(" ")
# Out:
# 1
# 2
# 3
#
# 4
# 5
# 6
#
# 7
# 8
# 9

# %%
### opertion in the tuple

# %%
num_1= 45
num_2 = 30
print(num_1+num_2)
# Out:
# 75

# %%
tup_1=(1,2,3)
tup_2=(4,5,6)
print(tup_1+tup_2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
### in tples + operation is goinging to concatinate
