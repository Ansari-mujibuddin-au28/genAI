# %% [markdown]
# Distionary

# %% [markdown]
# ### General

# %% [markdown]
# ### happy

# %% [markdown]
# ### sad

# %% [markdown]
# ### stntx of distionary is { key:value}

# %% [markdown]
# ### we want to store data in rows and columns

# %% [markdown]
# ### coulumns + rows
# ## name email phone

# %% [markdown]
# ### mujib hhhh 33333

# %% [markdown]
# ### "name" : ["amit]

# %% [markdown]
# ### { "name":["amit"], "email":[""acb@gmail],"phone":["1233"]}

# %%
dic={"name":"mujib","email":"abc@123","phone":"1234"}

# %%
dic
# Out:
# {'name': 'mujib', 'email': 'abc@123', 'phone': '1234'}

# %%
### dic are not index and it is mutable and we prefere to be immutable

# %%
# dic having key and value combination with that we can asscess key to fetch value

# %%
dic["name"]
# Out:
# 'mujib'

# %%
### del a dic item as well

# %%
del dic["phone"]

# %%
dic
# Out:
# {'name': 'mujib', 'email': 'abc@123'}

# %%
### Dic methodss

# %%
## keys

# %%
### value

# %%
### items

# %%
### get

# %%
dic={"nane":"mujib","email":"abc@gmail","phone":"1234","fruit":"apple","items":[1,2,3,]}

# %%
dic
# Out:
# {'nane': 'mujib',
#  'email': 'abc@gmail',
#  'phone': '1234',
#  'fruit': 'apple',
#  'items': [1, 2, 3]}

# %%
dic.values
# Out:
# <function dict.values>

# %%
dic.values()
# Out:
# dict_values(['mujib', 'abc@gmail', '1234', 'apple', [1, 2, 3]])

# %%
dic.items()
# Out:
# dict_items([('nane', 'mujib'), ('email', 'abc@gmail'), ('phone', '1234'), ('fruit', 'apple'), ('items', [1, 2, 3])])

# %%
dic.get("name")

# %%
dic.get("nane")
# Out:
# 'mujib'

# %%
### shallow copy is used to create a copy from original dic

# %%
dic_1={"name":"mujib","phone":"1234"}

# %%
dic_2={"name":"aaa","phone":"2222333"}

# %%
dic_1=dic_2.copy()

# %%
dic_1
# Out:
# {'name': 'aaa', 'phone': '2222333'}

# %%
dic_2
# Out:
# {'name': 'aaa', 'phone': '2222333'}

# %%
### nested dic

# %%
# this is used to keep another dic

# %%
nested_dic={"std":{"name":"abc","mark":"123"},"std2":{"name":"abcd","mark":"1235"},"std3":{"name":"abcdf","mark":"12356"}}

# %%
nested_dic
# Out:
# {'std': {'name': 'abc', 'mark': '123'},
#  'std2': {'name': 'abcd', 'mark': '1235'},
#  'std3': {'name': 'abcdf', 'mark': '12356'}}

# %%
#irretiate

# %%
for outer_key,outer_value in nested_dic.items():
    print(f"outer key:{outer_key} and oute value :{outer_value}")
    for key_1, value_1 in outer_value.items():
        print(f"key is use of :{key_1} and inner value is : {value_1}")
# Out:
# outer key:std and oute value :{'name': 'abc', 'mark': '123'}
# key is use of :name and inner value is : abc
# key is use of :mark and inner value is : 123
# outer key:std2 and oute value :{'name': 'abcd', 'mark': '1235'}
# key is use of :name and inner value is : abcd
# key is use of :mark and inner value is : 1235
# outer key:std3 and oute value :{'name': 'abcdf', 'mark': '12356'}
# key is use of :name and inner value is : abcdf
# key is use of :mark and inner value is : 12356

# %%
### Dic comprehencesin

# %%
### it is looping a dic along inside dic

# %%
### sync

# %%
###c{exp for item ittereate if condition}

# %%
comprehensive={x**2 for x in range(1,9)}

# %%
comprehensive
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64}

# %%
comprehensive={x:x**2 for x in range(9)}

# %%
comprehensive
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
comprehensive={x:x**2 for x in range(9) if x %2==0}

# %%
comprehensive
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
### merged dic

# %%
dic_1={"a":1,"b":2}

# %%
dic_2={"a":1,'b':4}

# %%
merge_dic={**dic_1,**dic_2}

# %%
merge_dic
# Out:
# {'a': 1, 'b': 4}
