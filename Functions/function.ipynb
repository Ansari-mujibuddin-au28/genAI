# %% [markdown]
# ### Function

# %% [markdown]
# ### fuunction is a block of code that ack as a perform a specific task

# %% [markdown]
# ### transulate the text to another language
# ### def question(parameters):
# ### Dostring
# ### function body
# ### return

# %%
## we are creating a function to transulate from englist to hindi language

def transulate(english):
    """this function is going to convert to eng to hin"""
    if english == "hello" or english == "Hello":
        print(f"the transulate for {english} test is namaste ")
    if english == "help" or english == "Help":
        print(f"the transulate for {english} test is Madadad ")
        
english=input("enter")
transulate(english)
# Out:
# the transulate for hello test is namaste

# %%
## we are creating a function to transulate from hin to eng language

def transulate(english):
    """this function is going to convert to eng to hin"""
    if english == "namaste" or english == "Namaste":
        hind_word="Hello"
                   
    elif english == "Madadad" or english == "madadad":
        hind_word="Help"
        
    return hind_word
        
english=input("enter")
transulate(english)
# Out:
# 'Help'

# %%
### functions are re usable once we create a global fun we can re use it any file 
def candidate(candidate):
    print(f"print greeting {candidate}")
candidate("neha")
# Out:
# print greeting neha

# %%
### problem statement using function
### creat a fun and take inpt from user and figure out the input num is even

def even(num):
    if num%2==0:
      return num
even(2)
# Out:
# 2

# %%
def even(num):
    if num%2==0:
      print("even")
    else:
       print("odd")
even(3)
# Out:
# odd

# %%
### Recursive is a function it calls it self again and again
### factorinal 8*7....2*1
### factorisl of 0 and i is 1

def factorial(num):
        if num==0 or num==1:
            print(num)
        else:
            factorial=1
            for i in range(1,num+1):
                factorial=factorial*i
            print(fac1torial)
factorial(3)
# Out:
# 6

# %%
def recursive(num):
    if num==0 or num==1:
         return 1
    else:
         return num*recursive(num-1)
recursive(5)
# Out:
# 120

# %%
### positional agruments we can pass n number of argument if use star * in  parameters

def function(*num):
    print(num)
function(1,2,3)
# Out:
# (1, 2, 3)

# %%
### keyword argments take the inputs as keywords which ha ** double start
def function(**data):
    for key,value in data.items():
        print(key,value)
function(name="sss",hhhh="llll")
# Out:
# name sss
# hhhh llll
