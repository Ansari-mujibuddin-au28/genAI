# %% [markdown]
# ### Lamda fn

# %% [markdown]
# ### lamda fn is a simple terms of one item fn can be written in 1 single fn
# ## lamda aruguument : expression
# ### lmda knows the current fn
# ## arument --> input
# ## expression -> logic (body)

# %% [markdown]
# ### They can have any number of arg but only one express or only one logic
# ### they are used for shot operations or as agrements to Hight order Function

# %% [markdown]
# ### it can be treated as a function with out and Name and dont have return statement

# %%
### function which calcualtes the square of the numers

def square(num):
    return num**2

# %%
square(5)
# Out:
# 25

# %%
### this simalar this we can use with lamda
lamda_fn= lambda x:x**2

# %%
lamda_fn(5)
# Out:
# 25

# %%
### lamda fun is used to calculate sum of 2 numbers
sum= lambda x,y:x+y
print(sum(5,5))
# Out:
# 10

# %%
product = lambda x,y,z:x*y*z

# %%
print(product(5,5,5))
# Out:
# 125
