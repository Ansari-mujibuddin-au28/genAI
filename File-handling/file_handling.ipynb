# %% [markdown]
# ### File Handling

# %% [markdown]
# ### Ram --> temperary
# ### file ->>> permently

# %% [markdown]
# ### NLP ---> TEXt data (sequential data) --> text formate file
# ### Machine Learning --> cat dog image classifiers -- png or jpeg - binary
# ### Deeping Learning ---> Object Calssifiers --> png or jpeg --> Binary formate file

# %% [markdown]
# ### types of File

# %% [markdown]
# ### 1 text file---> .txt.doc etc
# ### 2 binary ---> pmg .mp4 .mp3 .mpv etc

# %% [markdown]
# ### file handling
# ### dairy --> read the content from  my dairy
# ### 1 open dairy
# ### 2 read the contet
# ### 3 closing the diary
#
# ### writing the content into the dairy open--> write/read--> close

# %% [markdown]
# ### open()--> opening file
# ### first parameter --- file_name
# ## second paramenter --- mode
# ### mode --- it decides the way in which we are working with this file

# %%
### open()--> opening file
### first parameter --- file_name
## second paramenter --- mode
### mode --- it decides the way in which we are working with this file

'''Mode --> r ---> reading the content fron the File
Mode ---> w --- write
Mode --> r+ --- read the content and write 
Mode --> w+ ---> write and read '''
